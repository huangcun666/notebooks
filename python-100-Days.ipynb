# %%
from abc import ABCMeta,abstractclassmethod
from random import randint,randrange

class Fighter(object,metaclass=ABCMeta):
    __slots__=('_name','_hp')
    def __init__(self,name,hp):
        self._name=name
        self._hp=hp
    @property
    def name(self):
        return self._name
    @property
    def hp(self):
        return self._hp
    @hp.setter
    def hp(self,hp):
        self._hp=hp if hp>0 else 0
    @property
    def alive(self):
        return self._hp>0
    @abstractclassmethod
    def attack(self,other):
        pass

class Ultraman(Fighter):
    __slots__=('_name','_hp','_mp')
    
    def __init__(self,name,hp,mp):
        super().__init__(name,hp)
        self._mp=mp
    def attack(self,other):
        other.hp-=randint(12,25)
    def huge_attack(self,other):
        if self._mp>=50:
            self._mp-=50
            injury=other.hp*3/4
            injury=injury if injury>50 else 50
            other.hp-=injury
            return True
        else:
            self.attack(other)
            return False
    def magic_attack(self,others):
        if self._mp>=20:
            self._mp-=20
            for temp in others:
                temp.hp-=randint(10,15)
            return True
        else:
            return False
    def resume(self):
        incr_point=randint(1,10)
        self._mp+=incr_point
        return incr_point
    def __str__(self):
        return '~~~%s奥特曼~~~\n生命值:%d\n魔法值:%d\n'%(self._name,self.hp,self._mp)

class Monster(Fighter):
    __slots__=('_name','_hp')
    
    def attack(self,other):
        other.hp-=randint(10,20)
    def __str__(self):
        return '~~~%s小怪兽~~~\n生命值:%d\n'%(self._name,self._hp)
def is_any_alive(monsters):
    for monster in monsters:
        if monster.alive>0:
            return True
    return False
def select_alive_one(monsters):
    monsters_len=len(monsters)
    while True:
        index=randrange(monsters_len)
        monster=monsters[index]
        if monster.alive>0:
            return monster
def display_info(ultraman,monsters):
    print(ultraman)
    for monster in monsters:
        print(monster,end='')
        
def main():
    u=Ultraman('迪家',1000,120)
    m1=Monster('狄仁杰',250)
    m2=Monster('白眼房',500)
    m3=Monster('王大锤',700)
    ms=[m1,m2,m3]
    fight_round=1
    while u.alive and is_any_alive(ms):
        print('======第%02d回合======'%fight_round)
        m=select_alive_one(ms)
        skill=randint(1,10)
        if skill<=6:
            print('%s使用普通攻击打了%s.'%(u.name,m.name ))
            u.attack(m)
            print('%s的魔法值恢复了%d点.' % (u.name, u.resume()))
        elif skill <= 9:  # 30%的概率使用魔法攻击(可能因魔法值不足而失败)
            if u.magic_attack(ms):
                print('%s使用了魔法攻击.' % u.name)
            else:
                print('%s使用魔法失败.' % u.name)
        else:  # 10%的概率使用究极必杀技(如果魔法值不足则使用普通攻击)
            if u.huge_attack(m):
                print('%s使用究极必杀技虐了%s.' % (u.name, m.name))
            else:
                print('%s使用普通攻击打了%s.' % (u.name, m.name))
                print('%s的魔法值恢复了%d点.' % (u.name, u.resume()))
        if m.alive > 0:  # 如果选中的小怪兽没有死就回击奥特曼
            print('%s回击了%s.' % (m.name, u.name))
            m.attack(u)
        display_info(u, ms)  # 每个回合结束后显示奥特曼和小怪兽的信息
        fight_round += 1
    print('\n========战斗结束!========\n')
    if u.alive > 0:
        print('%s奥特曼胜利!' % u.name)
    else:
        print('小怪兽胜利!')


if __name__ == '__main__':
    main()
# Out:
# ======第01回合======
# 迪家使用普通攻击打了王大锤.
# 迪家的魔法值恢复了7点.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:985
# 魔法值:127
#
# ~~~狄仁杰小怪兽~~~
# 生命值:250
# ~~~白眼房小怪兽~~~
# 生命值:500
# ~~~王大锤小怪兽~~~
# 生命值:678
# ======第02回合======
# 迪家使用了魔法攻击.
# 狄仁杰回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:974
# 魔法值:107
#
# ~~~狄仁杰小怪兽~~~
# 生命值:238
# ~~~白眼房小怪兽~~~
# 生命值:485
# ~~~王大锤小怪兽~~~
# 生命值:664
# ======第03回合======
# 迪家使用普通攻击打了白眼房.
# 迪家的魔法值恢复了10点.
# 白眼房回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:954
# 魔法值:117
#
# ~~~狄仁杰小怪兽~~~
# 生命值:238
# ~~~白眼房小怪兽~~~
# 生命值:460
# ~~~王大锤小怪兽~~~
# 生命值:664
# ======第04回合======
# 迪家使用究极必杀技虐了白眼房.
# 白眼房回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:943
# 魔法值:67
#
# ~~~狄仁杰小怪兽~~~
# 生命值:238
# ~~~白眼房小怪兽~~~
# 生命值:115
# ~~~王大锤小怪兽~~~
# 生命值:664
# ======第05回合======
# 迪家使用普通攻击打了白眼房.
# 迪家的魔法值恢复了4点.
# 白眼房回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:929
# 魔法值:71
#
# ~~~狄仁杰小怪兽~~~
# 生命值:238
# ~~~白眼房小怪兽~~~
# 生命值:93
# ~~~王大锤小怪兽~~~
# 生命值:664
# ======第06回合======
# 迪家使用了魔法攻击.
# 狄仁杰回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:914
# 魔法值:51
#
# ~~~狄仁杰小怪兽~~~
# 生命值:224
# ~~~白眼房小怪兽~~~
# 生命值:83
# ~~~王大锤小怪兽~~~
# 生命值:652
# ======第07回合======
# 迪家使用了魔法攻击.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:898
# 魔法值:31
#
# ~~~狄仁杰小怪兽~~~
# 生命值:214
# ~~~白眼房小怪兽~~~
# 生命值:73
# ~~~王大锤小怪兽~~~
# 生命值:642
# ======第08回合======
# 迪家使用普通攻击打了白眼房.
# 迪家的魔法值恢复了4点.
# 白眼房回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:888
# 魔法值:35
#
# ~~~狄仁杰小怪兽~~~
# 生命值:214
# ~~~白眼房小怪兽~~~
# 生命值:51
# ~~~王大锤小怪兽~~~
# 生命值:642
# ======第09回合======
# 迪家使用普通攻击打了狄仁杰.
# 迪家的魔法值恢复了10点.
# 狄仁杰回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:868
# 魔法值:45
#
# ~~~狄仁杰小怪兽~~~
# 生命值:198
# ~~~白眼房小怪兽~~~
# 生命值:51
# ~~~王大锤小怪兽~~~
# 生命值:642
# ======第10回合======
# 迪家使用了魔法攻击.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:856
# 魔法值:25
#
# ~~~狄仁杰小怪兽~~~
# 生命值:187
# ~~~白眼房小怪兽~~~
# 生命值:38
# ~~~王大锤小怪兽~~~
# 生命值:629
# ======第11回合======
# 迪家使用普通攻击打了王大锤.
# 迪家的魔法值恢复了1点.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:841
# 魔法值:26
#
# ~~~狄仁杰小怪兽~~~
# 生命值:187
# ~~~白眼房小怪兽~~~
# 生命值:38
# ~~~王大锤小怪兽~~~
# 生命值:610
# ======第12回合======
# 迪家使用普通攻击打了狄仁杰.
# 迪家的魔法值恢复了1点.
# 狄仁杰回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:823
# 魔法值:27
#
# ~~~狄仁杰小怪兽~~~
# 生命值:162
# ~~~白眼房小怪兽~~~
# 生命值:38
# ~~~王大锤小怪兽~~~
# 生命值:610
# ======第13回合======
# 迪家使用普通攻击打了白眼房.
# 迪家的魔法值恢复了8点.
# 白眼房回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:805
# 魔法值:35
#
# ~~~狄仁杰小怪兽~~~
# 生命值:162
# ~~~白眼房小怪兽~~~
# 生命值:21
# ~~~王大锤小怪兽~~~
# 生命值:610
# ======第14回合======
# 迪家使用了魔法攻击.
# 白眼房回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:788
# 魔法值:15
#
# ~~~狄仁杰小怪兽~~~
# 生命值:147
# ~~~白眼房小怪兽~~~
# 生命值:7
# ~~~王大锤小怪兽~~~
# 生命值:600
# ======第15回合======
# 迪家使用魔法失败.
# 白眼房回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:772
# 魔法值:15
#
# ~~~狄仁杰小怪兽~~~
# 生命值:147
# ~~~白眼房小怪兽~~~
# 生命值:7
# ~~~王大锤小怪兽~~~
# 生命值:600
# ======第16回合======
# 迪家使用魔法失败.
# 白眼房回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:757
# 魔法值:15
#
# ~~~狄仁杰小怪兽~~~
# 生命值:147
# ~~~白眼房小怪兽~~~
# 生命值:7
# ~~~王大锤小怪兽~~~
# 生命值:600
# ======第17回合======
# 迪家使用普通攻击打了狄仁杰.
# 迪家的魔法值恢复了4点.
# 狄仁杰回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:740
# 魔法值:19
#
# ~~~狄仁杰小怪兽~~~
# 生命值:126
# ~~~白眼房小怪兽~~~
# 生命值:7
# ~~~王大锤小怪兽~~~
# 生命值:600
# ======第18回合======
# 迪家使用普通攻击打了王大锤.
# 迪家的魔法值恢复了5点.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:730
# 魔法值:24
#
# ~~~狄仁杰小怪兽~~~
# 生命值:126
# ~~~白眼房小怪兽~~~
# 生命值:7
# ~~~王大锤小怪兽~~~
# 生命值:585
# ======第19回合======
# 迪家使用普通攻击打了王大锤.
# 迪家的魔法值恢复了7点.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:712
# 魔法值:31
#
# ~~~狄仁杰小怪兽~~~
# 生命值:126
# ~~~白眼房小怪兽~~~
# 生命值:7
# ~~~王大锤小怪兽~~~
# 生命值:564
# ======第20回合======
# 迪家使用普通攻击打了狄仁杰.
# 迪家的魔法值恢复了3点.
# 狄仁杰回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:700
# 魔法值:34
#
# ~~~狄仁杰小怪兽~~~
# 生命值:108
# ~~~白眼房小怪兽~~~
# 生命值:7
# ~~~王大锤小怪兽~~~
# 生命值:564
# ======第21回合======
# 迪家使用了魔法攻击.
# ~~~迪家奥特曼~~~
# 生命值:700
# 魔法值:14
#
# ~~~狄仁杰小怪兽~~~
# 生命值:94
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:550
# ======第22回合======
# 迪家使用魔法失败.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:681
# 魔法值:14
#
# ~~~狄仁杰小怪兽~~~
# 生命值:94
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:550
# ======第23回合======
# 迪家使用普通攻击打了狄仁杰.
# 迪家的魔法值恢复了4点.
# 狄仁杰回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:667
# 魔法值:18
#
# ~~~狄仁杰小怪兽~~~
# 生命值:82
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:550
# ======第24回合======
# 迪家使用普通攻击打了狄仁杰.
# 迪家的魔法值恢复了4点.
# 狄仁杰回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:651
# 魔法值:22
#
# ~~~狄仁杰小怪兽~~~
# 生命值:57
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:550
# ======第25回合======
# 迪家使用普通攻击打了王大锤.
# 迪家的魔法值恢复了1点.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:632
# 魔法值:23
#
# ~~~狄仁杰小怪兽~~~
# 生命值:57
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:527
# ======第26回合======
# 迪家使用普通攻击打了狄仁杰.
# 迪家的魔法值恢复了10点.
# 狄仁杰回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:615
# 魔法值:33
#
# ~~~狄仁杰小怪兽~~~
# 生命值:43
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:527
# ======第27回合======
# 迪家使用普通攻击打了狄仁杰.
# 迪家的魔法值恢复了8点.
# 狄仁杰回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:602
# 魔法值:41
#
# ~~~狄仁杰小怪兽~~~
# 生命值:26
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:527
# ======第28回合======
# 迪家使用了魔法攻击.
# 狄仁杰回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:589
# 魔法值:21
#
# ~~~狄仁杰小怪兽~~~
# 生命值:16
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:512
# ======第29回合======
# 迪家使用普通攻击打了王大锤.
# 迪家的魔法值恢复了4点.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:576
# 魔法值:25
#
# ~~~狄仁杰小怪兽~~~
# 生命值:16
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:498
# ======第30回合======
# 迪家使用普通攻击打了狄仁杰.
# 迪家的魔法值恢复了5点.
# 狄仁杰回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:565
# 魔法值:30
#
# ~~~狄仁杰小怪兽~~~
# 生命值:2
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:498
# ======第31回合======
# 迪家使用普通攻击打了王大锤.
# 迪家的魔法值恢复了10点.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:549
# 魔法值:40
#
# ~~~狄仁杰小怪兽~~~
# 生命值:2
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:477
# ======第32回合======
# 迪家使用普通攻击打了狄仁杰.
# 迪家的魔法值恢复了4点.
# ~~~迪家奥特曼~~~
# 生命值:549
# 魔法值:44
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:477
# ======第33回合======
# 迪家使用了魔法攻击.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:538
# 魔法值:24
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:466
# ======第34回合======
# 迪家使用普通攻击打了王大锤.
# 迪家的魔法值恢复了8点.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:527
# 魔法值:32
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:454
# ======第35回合======
# 迪家使用了魔法攻击.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:510
# 魔法值:12
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:439
# ======第36回合======
# 迪家使用魔法失败.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:490
# 魔法值:12
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:439
# ======第37回合======
# 迪家使用普通攻击打了王大锤.
# 迪家的魔法值恢复了2点.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:474
# 魔法值:14
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:427
# ======第38回合======
# 迪家使用魔法失败.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:461
# 魔法值:14
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:427
# ======第39回合======
# 迪家使用魔法失败.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:447
# 魔法值:14
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:427
# ======第40回合======
# 迪家使用普通攻击打了王大锤.
# 迪家的魔法值恢复了6点.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:433
# 魔法值:20
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:415
# ======第41回合======
# 迪家使用普通攻击打了王大锤.
# 迪家的魔法值恢复了9点.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:422
# 魔法值:29
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:399
# ======第42回合======
# 迪家使用普通攻击打了王大锤.
# 迪家的魔法值恢复了2点.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:409
# 魔法值:31
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:386
# ======第43回合======
# 迪家使用普通攻击打了王大锤.
# 迪家的魔法值恢复了5点.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:393
# 魔法值:36
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:372
# ======第44回合======
# 迪家使用普通攻击打了王大锤.
# 迪家的魔法值恢复了4点.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:377
# 魔法值:40
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:349
# ======第45回合======
# 迪家使用普通攻击打了王大锤.
# 迪家的魔法值恢复了6点.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:366
# 魔法值:46
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:324
# ======第46回合======
# 迪家使用普通攻击打了王大锤.
# 迪家的魔法值恢复了6点.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:351
# 魔法值:52
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:301
# ======第47回合======
# 迪家使用普通攻击打了王大锤.
# 迪家的魔法值恢复了4点.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:334
# 魔法值:56
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:276
# ======第48回合======
# 迪家使用了魔法攻击.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:318
# 魔法值:36
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:265
# ======第49回合======
# 迪家使用普通攻击打了王大锤.
# 迪家的魔法值恢复了3点.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:305
# 魔法值:39
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:251
# ======第50回合======
# 迪家使用普通攻击打了王大锤.
# 迪家的魔法值恢复了4点.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:292
# 魔法值:43
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:233
# ======第51回合======
# 迪家使用普通攻击打了王大锤.
# 迪家的魔法值恢复了5点.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:281
# 魔法值:48
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:214
# ======第52回合======
# 迪家使用普通攻击打了王大锤.
# 迪家的魔法值恢复了10点.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:270
# 魔法值:58
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:193
# ======第53回合======
# 迪家使用普通攻击打了王大锤.
# 迪家的魔法值恢复了2点.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:253
# 魔法值:60
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:178
# ======第54回合======
# 迪家使用普通攻击打了王大锤.
# 迪家的魔法值恢复了7点.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:242
# 魔法值:67
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:160
# ======第55回合======
# 迪家使用了魔法攻击.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:229
# 魔法值:47
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:150
# ======第56回合======
# 迪家使用了魔法攻击.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:209
# 魔法值:27
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:139
# ======第57回合======
# 迪家使用普通攻击打了王大锤.
# 迪家的魔法值恢复了1点.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:197
# 魔法值:28
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:114
# ======第58回合======
# 迪家使用了魔法攻击.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:186
# 魔法值:8
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:102
# ======第59回合======
# 迪家使用魔法失败.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:170
# 魔法值:8
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:102
# ======第60回合======
# 迪家使用普通攻击打了王大锤.
# 迪家的魔法值恢复了3点.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:157
# 魔法值:11
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:86
# ======第61回合======
# 迪家使用普通攻击打了王大锤.
# 迪家的魔法值恢复了7点.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:147
# 魔法值:18
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:67
# ======第62回合======
# 迪家使用普通攻击打了王大锤.
# 迪家的魔法值恢复了4点.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:137
# 魔法值:22
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:46
# ======第63回合======
# 迪家使用普通攻击打了王大锤.
# 迪家的魔法值恢复了9点.
# 王大锤回击了迪家.
# ~~~迪家奥特曼~~~
# 生命值:119
# 魔法值:31
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:21
# ======第64回合======
# 迪家使用普通攻击打了王大锤.
# 迪家的魔法值恢复了6点.
# ~~~迪家奥特曼~~~
# 生命值:119
# 魔法值:37
#
# ~~~狄仁杰小怪兽~~~
# 生命值:0
# ~~~白眼房小怪兽~~~
# 生命值:0
# ~~~王大锤小怪兽~~~
# 生命值:0
#
# ========战斗结束!========
#
# 迪家奥特曼胜利!

# %%
import random
class Card(object):
    def __init__(self,suite,face):
        self._suite=suite
        self._face=face
    @property
    def suite(self):
        return self._suite
    @property
    def face(self):
        return self._face
    def __str__(self):
        if self._face=='1':
            face_str='A'
        elif self._face == 11:
            face_str = 'J'
        elif self._face == 12:
            face_str = 'Q'
        elif self._face == 13:
            face_str = 'K'
        else:
            face_str = str(self._face)
        return '%s%s' % (self._suite, face_str)
    def __repr__(self):
        return self.__str__()

class Poker(object):
    def __init__(self):
        self._cards=[Card(suite,face) for suite in '♠♥♣♦' for face in range(1,14)]
        self._current=0
        
    @property
    def cards(self):
        return self._cards
    def shuffle(self):
        self._current=0
        random.shuffle(self._cards)
    @property
    def next(self):
        card=self._cards[self._current]
        self._current+=1
        return card
    @property
    def has_next(self):
        return self._current<len(self._cards)

class Player(object):
    def __init__(self,name):
        self._name=name
        self._cards_on_hand=[]
        
    @property
    def name(self):
        return self._name
    @property
    def cards_on_hand(self):
        return self._cards_on_hand
    
    def get(self,card):
        self._cards_on_hand.append(card)
    def arrange(self,card_key):
        self._cards_on_hand.sort(key=card_key)

def get_key(card):
    return (card.suite,card.face)
def main():
    p=Poker()
    p.shuffle()
    players = [Player('东邪'), Player('西毒'), Player('南帝'), Player('北丐')]
    for _ in range(13):

        for player in players:
            
            player.get(p.next)
    for player in players:
        print(player.name+':',end=' ')
        player.arrange(get_key)
        print(player.cards_on_hand)
if __name__=='__main__':
    main()
# Out:
# 东邪: [♠J, ♣3, ♣10, ♣Q, ♥1, ♥2, ♥4, ♦3, ♦4, ♦6, ♦7, ♦8, ♦10]
# 西毒: [♠2, ♠8, ♠10, ♠K, ♣9, ♥5, ♥6, ♥J, ♥Q, ♥K, ♦1, ♦5, ♦K]
# 南帝: [♠3, ♠5, ♠6, ♠7, ♠Q, ♣2, ♣4, ♣8, ♣K, ♥3, ♥9, ♥10, ♦9]
# 北丐: [♠1, ♠4, ♠9, ♣1, ♣5, ♣6, ♣7, ♣J, ♥7, ♥8, ♦2, ♦J, ♦Q]

# %%
import tkinter
import tkinter.messagebox
def main():
    flag = True

    # 修改标签上的文字
    def change_label_text():
        nonlocal flag
        flag = not flag
        color, msg = ('red', 'Hello, world!')\
            if flag else ('blue', 'Goodbye, world!')
        label.config(text=msg, fg=color)

    # 确认退出
    def confirm_to_quit():
        if tkinter.messagebox.askokcancel('温馨提示', '确定要退出吗?'):
            top.quit()

    # 创建顶层窗口
    top = tkinter.Tk()
    # 设置窗口大小
    top.geometry('240x160')
    # 设置窗口标题
    top.title('小游戏')
    # 创建标签对象并添加到顶层窗口
    label = tkinter.Label(top, text='Hello, world!', font='Arial -32', fg='red')
    label.pack(expand=1)
    # 创建一个装按钮的容器
    panel = tkinter.Frame(top)
    # 创建按钮对象 指定添加到哪个容器中 通过command参数绑定事件回调函数
    button1 = tkinter.Button(panel, text='修改', command=change_label_text)
    button1.pack(side='left')
    button2 = tkinter.Button(panel, text='退出', command=confirm_to_quit)
    button2.pack(side='right')
    panel.pack(side='bottom')
    # 开启主事件循环
    tkinter.mainloop()


if __name__ == '__main__':
    main()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/tkinter/__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-2-709683e260d3>", line 16, in confirm_to_quit
#     if tkinter.messagebox.askokcancel('温馨提示', '确定要退出吗?'):
#   File "/usr/lib/python3.6/tkinter/messagebox.py", line 99, in askokcancel
#     s = _show(title, message, QUESTION, OKCANCEL, **options)
#   File "/usr/lib/python3.6/tkinter/messagebox.py", line 72, in _show
#     res = Message(**options).show()
#   File "/usr/lib/python3.6/tkinter/commondialog.py", line 43, in show
#     s = w.tk.call(self.command, *w._options(self.options))
# _tkinter.TclError: can't invoke "grab" command: application has been destroyed

# %%
import pygame,sys

def main():
    pygame.init()
    screen=pygame.display.set_mode((800,600))
    pygame.display.set_caption('大球吃小球')
    x,y=50,50
    running=True
    while running:
        for event in pygame.event.get():
            if event.type==pygame.QUIT:
                running=False
                pygame.quit()
        screen.fill((255,255,255))
        pygame.draw.circle(screen,(255,0,0),(x,y),30,0)
        pygame.display.flip()
        pygame.time.delay(50)
        x,y=x+5,y+5
if __name__=='__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-9-135eb0baf13c> in <module>
#      18         x,y=x+5,y+5
#      19 if __name__=='__main__':
# ---> 20     main()
#      21
#
# <ipython-input-9-135eb0baf13c> in main()
#      12                 running=False
#      13                 pygame.quit()
# ---> 14         screen.fill((255,255,255))
#      15         pygame.draw.circle(screen,(255,0,0),(x,y),30,0)
#      16         pygame.display.flip()
#
# error: display Surface quit

# %%
a=['1','2','3','4','5','6','7','8']
print(a[-1::-2])
# Out:
# ['8', '6', '4', '2']

# %%
from enum import Enum,unique
from math import sqrt
from random import randint

@unique
class Color(Enum):
    RED=(255,0,0)
    GREEN=(0,255,0)
    BLUE=(0,0,255)
    BLACK=(0,0,0)
    WHITE=(255,255,255)
    GRAY=(242,242,242)
    
    @staticmethod
    def random_color():
        r=randint(0,255)
        g=randint(0,255)
        b=randintq(0,255)
        return (r,g,b)

class Ball(object):
    def __init__(self,x,y,radius,sx,sy,color=Color.RED):
        self.x=x
        self.y=y
        self.radius=radius
        self.sx=sx
        self.sy=sy
        self.color=color
        self.alive=True
    
    def move(self,screen):
        self.x+=self.sx
        self.y+=self.sy
        if self.x-self.radius<=0 or self.x+self.radius>screen.get_width():
            self.sx=-self.sx
        if self.y-self.radius<=0 or self.y+self.radius>screen.get_height():
            self.y=-self.y
    
    def eat(self,other):
        if self.alive and other.alive and self!=other:
            dx,dy=abs(self.x-other.x),abs(self.y-other.y)
            distance=sqrt(dx ** 2+dy ** 2)
            if distance<self.radius+other.radius and self.radius>other.radius:
                other.alive=False
                self.radius=self.radius+int(other.radius*0.146)
    def draw(self, screen):
        pygame.draw.circle(screen,self.color,(self.x,self.y),self.radius,0)
# Out:
# hello, foo
# i am foo
# goodby, foo
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-7ea80d77048d> in <module>
#       8     print ("i am foo")
#       9
# ---> 10 foo()
#
# TypeError: 'NoneType' object is not callable

# %%
from math import sqrt
sqrt((-2) ** 2 + 3 ** 2)
# Out:
# 3.605551275463989
